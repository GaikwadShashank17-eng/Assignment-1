# %% [markdown]
# <a href="https://colab.research.google.com/github/GaikwadShashank17-eng/Assignment-1/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a list
numbers = [10, 20, 30, 40, 50]

# Check element presence
print(20 in numbers)      # True
print(60 not in numbers)  # True
# Out:
# True
# True

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

result = str1 + str2
print("Concatenated string:", result)
# Out:
# Enter first string: Hello
# Enter second string: Hii
# Concatenated string: Hello Hii
